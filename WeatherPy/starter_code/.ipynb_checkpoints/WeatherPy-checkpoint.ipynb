# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime as dtime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
def citi_list():
# Create a set of random lat and lng combinations
    lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
    lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
    lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
    for lat_lng in lat_lngs:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
        if city not in cities:
            cities.append(city)

# Print the city count to confirm sufficient count

while len(cities) < 500:
    citi_list()
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_list = []

def city_weather(clist):
    url = "http://api.openweathermap.org/data/2.5/weather?q="
    count = 0
    print('Beginning Data Retrieval')
    print('-----------------------------------------')
    for city in clist:
        count += 1
        r = requests.get(f"{url}{city}&units=imperial&APPID={api_key}")
        if r.status_code == 200:
            r = r.json()
            print(f"Getting records for {count}:{city}")
            weather_list.append(r)            
        else:
            print(f'{count}:{city} -- No weather data available for city, skipping')
            pass

city_weather(cities)
# Out:
# Beginning Data Retrieval
# -----------------------------------------
# Getting records for 1:hamilton
# Getting records for 2:hithadhoo
# Getting records for 3:hilo
# Getting records for 4:upernavik
# Getting records for 5:saint-philippe
# Getting records for 6:coahuayana
# 7:barentsburg -- No weather data available for city, skipping
# Getting records for 8:clyde river
# Getting records for 9:new norfolk
# 10:illoqqortoormiut -- No weather data available for city, skipping
# Getting records for 11:dikson
# Getting records for 12:karratha
# Getting records for 13:rikitea
# Getting records for 14:pacific grove
# Getting records for 15:sechura
# Getting records for 16:kaitangata
# Getting records for 17:dhidhdhoo
# Getting records for 18:tiznit
# Getting records for 19:chupa
# Getting records for 20:paraiso
# Getting records for 21:hobart
# 22:kamenskoye -- No weather data available for city, skipping
# Getting records for 23:ushuaia
# Getting records for 24:cidreira
# Getting records for 25:klaksvik
# Getting records for 26:buraydah
# Getting records for 27:salalah
# Getting records for 28:tessalit
# Getting records for 29:vaini
# 30:korla -- No weather data available for city, skipping
# Getting records for 31:punta arenas
# Getting records for 32:mahebourg
# 33:ngukurr -- No weather data available for city, skipping
# 34:taolanaro -- No weather data available for city, skipping
# Getting records for 35:barrow
# Getting records for 36:cabo san lucas
# Getting records for 37:kodiak
# Getting records for 38:tigil
# Getting records for 39:busselton
# Getting records for 40:forest grove
# Getting records for 41:tasiilaq
# Getting records for 42:albany
# Getting records for 43:hermanus
# Getting records for 44:ailigandi
# Getting records for 45:bambous virieux
# Getting records for 46:itoman
# Getting records for 47:iquique
# Getting records for 48:avarua
# Getting records for 49:havre-saint-pierre
# 50:deh rawud -- No weather data available for city, skipping
# Getting records for 51:yulara
# Getting records for 52:cooma
# Getting records for 53:victoria
# Getting records for 54:saint george
# Getting records for 55:delta del tigre
# Getting records for 56:merritt island
# Getting records for 57:dessel
# Getting records for 58:lebork
# Getting records for 59:sao filipe
# Getting records for 60:faanui
# Getting records for 61:vila
# Getting records for 62:hearst
# Getting records for 63:prainha
# Getting records for 64:boulder
# Getting records for 65:bluff
# Getting records for 66:sisimiut
# 67:vaitupu -- No weather data available for city, skipping
# Getting records for 68:enterprise
# Getting records for 69:santa elena
# Getting records for 70:aklavik
# Getting records for 71:la ronge
# Getting records for 72:qaanaaq
# Getting records for 73:nikolskoye
# Getting records for 74:bata
# 75:bolungarvik -- No weather data available for city, skipping
# Getting records for 76:mar del plata
# Getting records for 77:atar
# Getting records for 78:sistranda
# Getting records for 79:kavieng
# Getting records for 80:kapaa
# 81:bousso -- No weather data available for city, skipping
# Getting records for 82:antalaha
# Getting records for 83:fairbanks
# Getting records for 84:payson
# Getting records for 85:atuona
# Getting records for 86:sibolga
# Getting records for 87:tuktoyaktuk
# Getting records for 88:doha
# Getting records for 89:jamestown
# Getting records for 90:kruisfontein
# Getting records for 91:airai
# 92:attawapiskat -- No weather data available for city, skipping
# Getting records for 93:mwinilunga
# Getting records for 94:khatanga
# Getting records for 95:dossor
# Getting records for 96:cape town
# Getting records for 97:ponta do sol
# Getting records for 98:hasaki
# Getting records for 99:pangnirtung
# Getting records for 100:luganville
# Getting records for 101:kovrov
# Getting records for 102:kahului
# Getting records for 103:okhotsk
# Getting records for 104:grafton
# Getting records for 105:xichang
# Getting records for 106:laguna
# Getting records for 107:longyearbyen
# Getting records for 108:bethel
# Getting records for 109:rio bueno
# Getting records for 110:yerbogachen
# Getting records for 111:north bend
# Getting records for 112:arraial do cabo
# Getting records for 113:mataura
# Getting records for 114:chimala
# Getting records for 115:khiri mat
# Getting records for 116:taywarah
# Getting records for 117:port alfred
# Getting records for 118:mitsamiouli
# Getting records for 119:vilhena
# Getting records for 120:makakilo city
# Getting records for 121:shimoda
# Getting records for 122:kavaratti
# Getting records for 123:nanortalik
# Getting records for 124:guerrero negro
# Getting records for 125:presidencia roque saenz pena
# Getting records for 126:mulege
# Getting records for 127:clearlake
# Getting records for 128:gladstone
# Getting records for 129:sobolevo
# Getting records for 130:zabid
# Getting records for 131:severo-kurilsk
# Getting records for 132:tutoia
# Getting records for 133:esperance
# Getting records for 134:hobyo
# Getting records for 135:ostrovnoy
# Getting records for 136:egvekinot
# Getting records for 137:cayenne
# Getting records for 138:oyama
# Getting records for 139:pevek
# Getting records for 140:narsaq
# Getting records for 141:burnie
# Getting records for 142:bogoslovka
# Getting records for 143:ponta delgada
# Getting records for 144:quatre cocos
# Getting records for 145:porto murtinho
# Getting records for 146:saint-francois
# Getting records for 147:yellowknife
# Getting records for 148:saldanha
# 149:mentok -- No weather data available for city, skipping
# Getting records for 150:lebu
# Getting records for 151:kasongo-lunda
# Getting records for 152:ribeira grande
# Getting records for 153:newton
# Getting records for 154:acajutla
# 155:amderma -- No weather data available for city, skipping
# Getting records for 156:broome
# Getting records for 157:elko
# 158:palabuhanratu -- No weather data available for city, skipping
# Getting records for 159:butaritari
# Getting records for 160:port moresby
# 161:grand river south east -- No weather data available for city, skipping
# Getting records for 162:mehtar lam
# Getting records for 163:dingle
# Getting records for 164:nouadhibou
# 165:paucartambo -- No weather data available for city, skipping
# Getting records for 166:khonsa
# Getting records for 167:severodvinsk
# Getting records for 168:port hedland
# Getting records for 169:rawlins
# Getting records for 170:belaya gora
# Getting records for 171:castro
# Getting records for 172:tocopilla
# Getting records for 173:bathsheba
# 174:asau -- No weather data available for city, skipping
# Getting records for 175:lyantonde
# Getting records for 176:mao
# Getting records for 177:luderitz
# Getting records for 178:ampanihy
# Getting records for 179:guozhen
# Getting records for 180:pangai
# Getting records for 181:dunedin
# Getting records for 182:lewiston
# Getting records for 183:tias
# Getting records for 184:lower hutt
# Getting records for 185:severomuysk
# 186:belushya guba -- No weather data available for city, skipping
# Getting records for 187:whitianga
# 188:safaqis -- No weather data available for city, skipping
# Getting records for 189:cherskiy
# Getting records for 190:sabang
# Getting records for 191:ucluelet
# Getting records for 192:bhatkal
# Getting records for 193:porto belo
# Getting records for 194:loandjili
# Getting records for 195:prince rupert
# Getting records for 196:columbia
# Getting records for 197:zhigansk
# Getting records for 198:norman wells
# Getting records for 199:emerald
# Getting records for 200:erzin
# Getting records for 201:dongsheng
# Getting records for 202:akureyri
# Getting records for 203:medina
# Getting records for 204:otjimbingwe
# Getting records for 205:raisinghnagar
# Getting records for 206:tuatapere
# Getting records for 207:rio gallegos
# 208:tawnat -- No weather data available for city, skipping
# Getting records for 209:quito
# 210:mys shmidta -- No weather data available for city, skipping
# Getting records for 211:meulaboh
# Getting records for 212:novokayakent
# Getting records for 213:bredasdorp
# Getting records for 214:naron
# Getting records for 215:leh
# Getting records for 216:nhulunbuy
# Getting records for 217:souillac
# Getting records for 218:muravlenko
# Getting records for 219:torbay
# Getting records for 220:fortuna
# Getting records for 221:the valley
# Getting records for 222:mokhsogollokh
# Getting records for 223:sorland
# Getting records for 224:lavrentiya
# 225:sentyabrskiy -- No weather data available for city, skipping
# 226:kemijarvi -- No weather data available for city, skipping
# Getting records for 227:mukdahan
# Getting records for 228:kirakira
# Getting records for 229:vila franca do campo
# Getting records for 230:luanda
# Getting records for 231:lompoc
# Getting records for 232:ginir
# Getting records for 233:paragominas
# Getting records for 234:saint-pierre
# 235:samusu -- No weather data available for city, skipping
# Getting records for 236:kiunga
# Getting records for 237:isangel
# Getting records for 238:waverly
# Getting records for 239:los llanos de aridane
# Getting records for 240:whithorn
# Getting records for 241:beloha
# Getting records for 242:half moon bay
# Getting records for 243:baijiantan
# Getting records for 244:flinders
# Getting records for 245:saurimo
# Getting records for 246:iqaluit
# Getting records for 247:georgetown
# Getting records for 248:bad hofgastein
# Getting records for 249:izyaslav
# Getting records for 250:chongwe
# Getting records for 251:westport
# 252:ambodifototra -- No weather data available for city, skipping
# Getting records for 253:saskylakh
# Getting records for 254:port blair
# Getting records for 255:talaya
# Getting records for 256:san juan
# Getting records for 257:tynda
# Getting records for 258:lola
# Getting records for 259:necochea
# Getting records for 260:mgandu
# Getting records for 261:cloquet
# Getting records for 262:calabozo
# Getting records for 263:colares
# Getting records for 264:yacuiba
# Getting records for 265:cobourg
# Getting records for 266:rapar
# Getting records for 267:volnovakha
# Getting records for 268:tiksi
# Getting records for 269:ambulu
# Getting records for 270:dutlwe
# Getting records for 271:phuket
# Getting records for 272:simbahan
# 273:jiddah -- No weather data available for city, skipping
# 274:tungkang -- No weather data available for city, skipping
# Getting records for 275:quebec
# Getting records for 276:uyuni
# Getting records for 277:port augusta
# Getting records for 278:el alto
# Getting records for 279:maltahohe
# 280:ust-kamchatsk -- No weather data available for city, skipping
# 281:marcona -- No weather data available for city, skipping
# Getting records for 282:comodoro rivadavia
# Getting records for 283:kozulka
# Getting records for 284:izegem
# Getting records for 285:ambilobe
# Getting records for 286:biltine
# Getting records for 287:murakami
# Getting records for 288:puerto ayora
# 289:kachikau -- No weather data available for city, skipping
# Getting records for 290:sao jose da coroa grande
# Getting records for 291:itarema
# Getting records for 292:cockburn town
# Getting records for 293:bilibino
# Getting records for 294:calvinia
# Getting records for 295:novoukrainskiy
# Getting records for 296:labuhan
# 297:svetlyy -- No weather data available for city, skipping
# Getting records for 298:mount pleasant
# Getting records for 299:husavik
# Getting records for 300:kerrobert
# Getting records for 301:morant bay
# Getting records for 302:chokurdakh
# Getting records for 303:kushiro
# Getting records for 304:nalobikha
# Getting records for 305:ust-tsilma
# Getting records for 306:san patricio
# Getting records for 307:margate
# 308:bardiyah -- No weather data available for city, skipping
# Getting records for 309:harper
# Getting records for 310:moron
# Getting records for 311:mehamn
# Getting records for 312:muros
# Getting records for 313:mpika
# Getting records for 314:obera
# Getting records for 315:umm lajj
# Getting records for 316:nantong
# Getting records for 317:nemuro
# Getting records for 318:ferreira do alentejo
# Getting records for 319:moose factory
# Getting records for 320:umm kaddadah
# Getting records for 321:wanning
# 322:bengkulu -- No weather data available for city, skipping
# Getting records for 323:sechelt
# Getting records for 324:port hardy
# 325:acarau -- No weather data available for city, skipping
# Getting records for 326:surskoye
# 327:bargal -- No weather data available for city, skipping
# 328:sakakah -- No weather data available for city, skipping
# Getting records for 329:grindavik
# Getting records for 330:marfino
# Getting records for 331:berlevag
# Getting records for 332:pitimbu
# Getting records for 333:espanola
# Getting records for 334:loei
# Getting records for 335:rocha
# Getting records for 336:kastamonu
# 337:nizhneyansk -- No weather data available for city, skipping
# Getting records for 338:santa maria
# Getting records for 339:progreso
# Getting records for 340:pisco
# 341:tsihombe -- No weather data available for city, skipping
# Getting records for 342:ahipara
# Getting records for 343:mae sai
# Getting records for 344:thompson
# Getting records for 345:maykop
# Getting records for 346:santa vitoria do palmar
# Getting records for 347:bonthe
# Getting records for 348:chuy
# Getting records for 349:katsuura
# Getting records for 350:teya
# Getting records for 351:leningradskiy
# Getting records for 352:boa vista
# Getting records for 353:bandarbeyla
# Getting records for 354:lamas
# Getting records for 355:price
# Getting records for 356:kamsack
# Getting records for 357:manitouwadge
# Getting records for 358:amparafaravola
# Getting records for 359:rorvik
# Getting records for 360:bang saphan
# Getting records for 361:billings
# Getting records for 362:oranjemund
# Getting records for 363:port lincoln
# Getting records for 364:balikpapan
# Getting records for 365:liku
# Getting records for 366:zhaotong
# 367:tumannyy -- No weather data available for city, skipping
# Getting records for 368:vanimo
# Getting records for 369:yenagoa
# 370:saleaula -- No weather data available for city, skipping
# Getting records for 371:namatanai
# Getting records for 372:petropavlovsk-kamchatskiy
# Getting records for 373:college
# 374:stornoway -- No weather data available for city, skipping
# Getting records for 375:ilulissat
# Getting records for 376:monze
# Getting records for 377:gat
# Getting records for 378:san nicola
# Getting records for 379:cururupu
# Getting records for 380:arsenyev
# Getting records for 381:santiago del estero
# Getting records for 382:bilma
# Getting records for 383:palmeira
# Getting records for 384:kirensk
# Getting records for 385:east london
# Getting records for 386:bud
# Getting records for 387:puerto del rosario
# Getting records for 388:manaira
# 389:umzimvubu -- No weather data available for city, skipping
# Getting records for 390:tres arroyos
# Getting records for 391:shimanovsk
# Getting records for 392:nha trang
# Getting records for 393:bawku
# Getting records for 394:florence
# Getting records for 395:rognan
# Getting records for 396:carnarvon
# Getting records for 397:vung tau
# Getting records for 398:saint-augustin
# Getting records for 399:mackenzie
# Getting records for 400:lewistown
# Getting records for 401:san cristobal
# Getting records for 402:barabai
# Getting records for 403:goundam
# Getting records for 404:iralaya
# 405:tabiauea -- No weather data available for city, skipping
# Getting records for 406:santa rosa
# 407:meyungs -- No weather data available for city, skipping
# Getting records for 408:udachnyy
# Getting records for 409:monster
# Getting records for 410:wajid
# Getting records for 411:tsiroanomandidy
# Getting records for 412:rockland
# Getting records for 413:hailun
# 414:domoni -- No weather data available for city, skipping
# Getting records for 415:saint-ambroise
# Getting records for 416:beroroha
# 417:wad madani -- No weather data available for city, skipping
# Getting records for 418:ancud
# Getting records for 419:kaabong
# Getting records for 420:challapata
# Getting records for 421:sarangani
# Getting records for 422:darnah
# Getting records for 423:salmon arm
# Getting records for 424:bahir dar
# Getting records for 425:abreus
# Getting records for 426:houston
# Getting records for 427:concepcion del uruguay
# Getting records for 428:puerto santander
# Getting records for 429:nishihara
# Getting records for 430:montepuez
# 431:toftir -- No weather data available for city, skipping
# Getting records for 432:pathein
# Getting records for 433:hambantota
# Getting records for 434:tshikapa
# Getting records for 435:nyuksenitsa
# Getting records for 436:santa cruz
# Getting records for 437:estelle
# 438:katsiveli -- No weather data available for city, skipping
# Getting records for 439:ladario
# Getting records for 440:fengzhen
# Getting records for 441:eirunepe
# Getting records for 442:miandrivazo
# Getting records for 443:bandar-e lengeh
# 444:ayiasos -- No weather data available for city, skipping
# Getting records for 445:takoradi
# Getting records for 446:christchurch
# Getting records for 447:touros
# Getting records for 448:haines junction
# Getting records for 449:suntar
# Getting records for 450:kosonsoy
# Getting records for 451:havoysund
# Getting records for 452:darhan
# Getting records for 453:ketchikan
# Getting records for 454:solnechnyy
# Getting records for 455:talcahuano
# Getting records for 456:goya
# Getting records for 457:taoudenni
# 458:sinjah -- No weather data available for city, skipping
# Getting records for 459:kyabe
# Getting records for 460:maralal
# Getting records for 461:mitu
# Getting records for 462:kochi
# Getting records for 463:kerman
# Getting records for 464:hofn
# 465:utiroa -- No weather data available for city, skipping
# Getting records for 466:sao joao da barra
# Getting records for 467:sept-iles
# Getting records for 468:menongue
# Getting records for 469:coquimbo
# Getting records for 470:minab
# Getting records for 471:kushima
# 472:louisbourg -- No weather data available for city, skipping
# Getting records for 473:goderich
# Getting records for 474:tapes
# Getting records for 475:qixingtai
# Getting records for 476:lakes entrance
# Getting records for 477:komsomolskiy
# Getting records for 478:luorong
# Getting records for 479:chunskiy
# Getting records for 480:lowestoft
# Getting records for 481:mino
# Getting records for 482:provideniya
# Getting records for 483:dire
# Getting records for 484:hokitika
# Getting records for 485:tezu
# Getting records for 486:ballina
# Getting records for 487:dubki
# Getting records for 488:saravan
# Getting records for 489:prado
# Getting records for 490:praia da vitoria
# Getting records for 491:lerwick
# Getting records for 492:northam
# Getting records for 493:fare
# 494:ospina perez -- No weather data available for city, skipping
# Getting records for 495:sitka
# 496:wahran -- No weather data available for city, skipping
# Getting records for 497:saint-paul
# Getting records for 498:kibondo
# Getting records for 499:juneau
# Getting records for 500:de-kastri
# Getting records for 501:ondjiva
# Getting records for 502:wellington
# Getting records for 503:ardesen
# Getting records for 504:snezhnogorsk
# Getting records for 505:te anau
# Getting records for 506:plettenberg bay
# Getting records for 507:mananjary
# Getting records for 508:guye
# Getting records for 509:ayorou
# Getting records for 510:shache
# Getting records for 511:magadan
# Getting records for 512:vostok
# Getting records for 513:adrar
# Getting records for 514:ust-maya
# 515:kadykchan -- No weather data available for city, skipping
# Getting records for 516:miraflores
# Getting records for 517:devonport
# Getting records for 518:bajil
# Getting records for 519:beyneu
# Getting records for 520:ishinomaki
# Getting records for 521:ust-omchug
# Getting records for 522:isugod
# Getting records for 523:sibenik
# Getting records for 524:calvia
# Getting records for 525:grande prairie
# Getting records for 526:lhokseumawe
# Getting records for 527:aksha
# Getting records for 528:waddan
# Getting records for 529:amapa
# Getting records for 530:silver city
# Getting records for 531:guarda
# Getting records for 532:port-gentil
# 533:sorvag -- No weather data available for city, skipping
# Getting records for 534:san jeronimo
# Getting records for 535:abingdon
# Getting records for 536:urdoma
# Getting records for 537:albury
# 538:santa eulalia del rio -- No weather data available for city, skipping
# Getting records for 539:puerto carreno
# Getting records for 540:wonthaggi
# Getting records for 541:la palma
# Getting records for 542:najran
# 543:kazalinsk -- No weather data available for city, skipping
# Getting records for 544:general roca
# Getting records for 545:havelock
# Getting records for 546:vardo
# Getting records for 547:liverpool
# 548:stoyba -- No weather data available for city, skipping
# Getting records for 549:humaita
# Getting records for 550:ferkessedougou
# Getting records for 551:sinnamary
# Getting records for 552:vao
# Getting records for 553:santa isabel do rio negro
# Getting records for 554:mayumba
# Getting records for 555:minudasht
# Getting records for 556:peterborough
# Getting records for 557:kholmogory
# Getting records for 558:saint-denis
# Getting records for 559:chelmza
# Getting records for 560:masumbwe
# Getting records for 561:sulangan
# Getting records for 562:nerchinskiy zavod
# 563:saleilua -- No weather data available for city, skipping
# Getting records for 564:acapulco
# Getting records for 565:lufilufi
# Getting records for 566:gizo
# Getting records for 567:chara
# 568:verdalsora -- No weather data available for city, skipping
# Getting records for 569:nuevo progreso
# Getting records for 570:avera
# Getting records for 571:koundara
# Getting records for 572:yumen
# 573:krasnoselkup -- No weather data available for city, skipping
# Getting records for 574:yatou
# Getting records for 575:kendallville
# Getting records for 576:anloga
# Getting records for 577:constitucion
# Getting records for 578:sorong
# Getting records for 579:lebanon
# Getting records for 580:aksarka
# 581:maghama -- No weather data available for city, skipping
# Getting records for 582:freeport
# Getting records for 583:lorengau
# Getting records for 584:monrovia
# Getting records for 585:kilosa
# Getting records for 586:eyl
# Getting records for 587:naze
# Getting records for 588:kenai
# Getting records for 589:novoorsk
# Getting records for 590:daru
# Getting records for 591:kedougou
# Getting records for 592:hervey bay
# Getting records for 593:berdigestyakh
# Getting records for 594:upington
# Getting records for 595:petropavlovka
# 596:sataua -- No weather data available for city, skipping
# Getting records for 597:tucuman
# Getting records for 598:ust-koksa
# Getting records for 599:lagoa
# Getting records for 600:kieta
# Getting records for 601:pozo colorado
# Getting records for 602:eyemouth
# Getting records for 603:kalmunai
# Getting records for 604:mahibadhoo
# Getting records for 605:lilongwe
# Getting records for 606:lujan
# Getting records for 607:omsukchan
# 608:one hundred mile house -- No weather data available for city, skipping
# Getting records for 609:kampot
# Getting records for 610:wad rawah
# Getting records for 611:lewisporte
# 612:arrecife -- No weather data available for city, skipping
# Getting records for 613:balbalan
# Getting records for 614:galich

# %%
raw_df = pd.DataFrame(weather_list)
raw_df.head()
# Out:
#                             coord  \
# 0   {'lon': -79.87, 'lat': 43.26}
# 1     {'lon': 73.08, 'lat': -0.6}
# 2  {'lon': -155.08, 'lat': 19.71}
# 3   {'lon': -56.15, 'lat': 72.79}
# 4   {'lon': -73.48, 'lat': 45.36}
#
#                                              weather      base  \
# 0  [{'id': 600, 'main': 'Snow', 'description': 'l...  stations
# 1  [{'id': 804, 'main': 'Clouds', 'description': ...     model
# 2  [{'id': 501, 'main': 'Rain', 'description': 'm...  stations
# 3  [{'id': 804, 'main': 'Clouds', 'description': ...     model
# 4  [{'id': 800, 'main': 'Clear', 'description': '...  stations
#
#                                                 main  visibility  \
# 0  {'temp': 30.87, 'feels_like': 20.7, 'temp_min'...      2012.0
# 1  {'temp': 84.33, 'feels_like': 87.33, 'temp_min...         NaN
# 2  {'temp': 64.42, 'feels_like': 65.48, 'temp_min...      8047.0
# 3  {'temp': -30.44, 'feels_like': -46.25, 'temp_m...         NaN
# 4  {'temp': 13.95, 'feels_like': 5.97, 'temp_min'...     14484.0
#
#                                           wind        clouds          dt  \
# 0  {'speed': 11.41, 'deg': 180, 'gust': 19.46}   {'all': 90}  1578281925
# 1                  {'speed': 12.73, 'deg': 62}  {'all': 100}  1578281926
# 2                  {'speed': 3.36, 'deg': 240}   {'all': 90}  1578281652
# 3                 {'speed': 15.59, 'deg': 358}   {'all': 94}  1578281926
# 4                  {'speed': 3.36, 'deg': 340}    {'all': 1}  1578281881
#
#                                                  sys  timezone       id  \
# 0  {'type': 1, 'id': 818, 'country': 'CA', 'sunri...    -18000  5969785
# 1  {'country': 'MV', 'sunrise': 1578272902, 'suns...     18000  1282256
# 2  {'type': 1, 'id': 7881, 'country': 'US', 'sunr...    -36000  5855927
# 3       {'country': 'GL', 'sunrise': 0, 'sunset': 0}    -10800  3418910
# 4  {'type': 1, 'id': 820, 'country': 'CA', 'sunri...    -18000  6138908
#
#              name  cod          rain snow
# 0        Hamilton  200           NaN  NaN
# 1       Hithadhoo  200           NaN  NaN
# 2            Hilo  200  {'1h': 3.05}  NaN
# 3       Upernavik  200           NaN  NaN
# 4  Saint-Philippe  200           NaN  NaN

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
raw_df.to_csv(output_data_file)
raw_df.shape
# Out:
# (548, 15)

# %%
co_codes = []
for cord_pair in raw_df['coord']:
    city = citipy.nearest_city(cord_pair['lat'], cord_pair['lon'])
    co_codes.append(city.country_code)

# %%
df_main = pd.DataFrame(raw_df['name'])
df_main['Country'] = co_codes

def df_builder(var, sub_var):
    var_list = []
    for idx, ele in enumerate(raw_df[var]):
        var_list.append(raw_df[var][idx][sub_var])
    df_main[f'{sub_var}'.capitalize()] = var_list
df_builder('coord','lat')
df_builder('coord','lon')
df_builder('main','temp_max')
df_builder('main','humidity')
df_builder('wind','speed')
df_builder('clouds','all')
df_builder('main','temp_max')
df_main['Time'] = raw_df['dt']
df_main = df_main.rename(columns = {'name':'City','All': 'Cloudiness', 'Speed':'Wind Speed', 'Temp_max':'Max Temp'})

# %%
df_main
# Out:
#                City Country    Lat     Lon  Max Temp  Humidity  Wind Speed  \
# 0          Hamilton      ca  43.26  -79.87     33.01       100       11.41
# 1         Hithadhoo      mv  -0.60   73.08     84.33        73       12.73
# 2              Hilo      us  19.71 -155.08     71.60        83        3.36
# 3         Upernavik      gl  72.79  -56.15    -30.44        96       15.59
# 4    Saint-Philippe      ca  45.36  -73.48     19.99        66        3.36
# ..              ...     ...    ...     ...       ...       ...         ...
# 543          Kampot      kh  10.62  104.18     84.20        54        1.12
# 544       Wad Rawah      sd  15.16   33.13     55.17        24       10.25
# 545      Lewisporte      ca  49.25  -55.06     27.00        92       18.34
# 546        Balbalan      ph  17.44  121.20     71.55        60        4.94
# 547          Galich      ru  58.38   42.35     21.07        92        4.92
#
#      Cloudiness        Time
# 0            90  1578281925
# 1           100  1578281926
# 2            90  1578281652
# 3            94  1578281926
# 4             1  1578281881
# ..          ...         ...
# 543          44  1578282043
# 544           0  1578282043
# 545          90  1578282043
# 546          11  1578282044
# 547          99  1578282044
#
# [548 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Out:
# '01/05/2020'

# %%
def ploter(ind,dep):
    plt_date = dtime.today().strftime('%m/%d/%Y')
    x = df_main[ind]
    y = df_main[dep]
    plt.title(f'City Latitude vs. {dep}, ({plt_date})')
    plt.grid()
    plt.scatter(x,y, c = 'darkcyan',alpha = 0.65,
                edgecolors = 'black')

# %%
# plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plot1 = ploter('Lat', 'Max Temp')
plt.savefig("output_data/Max_Temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plot2 = ploter('Lat', 'Humidity')
plt.savefig("output_data/Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plot3 = ploter('Lat', 'Cloudiness')
plt.savefig("output_data/Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plot4 = ploter('Lat', 'Wind Speed')
plt.savefig("output_data/Wind_Speed.png")

# %% [markdown]
# # OBSERVATIONS

# %% [markdown]
# #### 1. From the Latitude vs. Max Temperature plot we can see how the points reach a peak before 0 degrees latitude and then start to decrease. This is to be expected as all the cities below the equator are experiencing summer seasons while cities above the equator are experiencing winter seasons.
#
# #### 2. The second plot comparing latitude to humidity shows that there isn't a strong relationship between the two variables. There is a higher concentration of cities with high levels of humidity as latitude increases. This could be a result of different seasons as the cities south of the equator are experiencing summer seasons which could be drier than others.
#
# #### 3. Based on the third plot comparing latitude to cloudiness shows that there is no visible relationship between them. Regardless of the location of the city, cloudiness seems to be independent of its latitude.
#
# #### 4. The final plot comparing latitude and wind speed fails to reveal any relationship between the two variables.  At the extremes of the X axis (north and south poles) we can see there is a greater variation in wind speeds while cities between -40 and 60 degrees latitude seem to have a smaller level of variation and are more evenly distributed.
